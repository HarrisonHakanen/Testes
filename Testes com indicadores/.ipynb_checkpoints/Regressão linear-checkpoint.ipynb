# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from   sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from   sklearn.metrics import r2_score
import statsmodels.api as sm
import os

import yfinance as yf
from datetime import datetime

import plotly
import plotly.express as px
import pandas as pd

import dateutil.relativedelta
from datetime import datetime

import plotly.graph_objects as go

# %%
ticker ="SOMA3.SA"

acao = yf.download(ticker)

acao_regressao = acao["2010-12-19":"2022-12-19"]
acao_regressao.reset_index(inplace=True)


X = acao_regressao.index.values.reshape(-1,1)
y = acao_regressao['Close'].values.reshape(-1,1)

#Regressão linear
reg = LinearRegression()
reg.fit(X, y)

f_previsoes = reg.predict(X)


previsoes_lista = list()
i = 0

while i < len(f_previsoes):
    
    previsoes_lista.append(f_previsoes[i][0])
    
    i+=1
    



#Regressão polinomial
poly = PolynomialFeatures(degree = 4)
X_poly = poly.fit_transform(X)
  
poly.fit(X_poly, y)
lin2 = LinearRegression()
lin2.fit(X_poly, y)

f_polinomial = lin2.predict(poly.fit_transform(X))

previsoes_polinomial = list()

i = 0

while i < len(f_polinomial):
    
    previsoes_polinomial.append(f_polinomial[i][0])
    
    i+=1



fig = go.Figure()

fig.add_trace(go.Candlestick(
name='Fechamento', 
x=acao_regressao["Date"], 
open=acao_regressao["Open"], 
high=acao_regressao["High"],
low=acao_regressao["Low"],
close=acao_regressao["Close"]))

fig.add_trace(
    go.Scatter(
        name="Regressão linear",
        x=acao_regressao["Date"],
        y=previsoes_lista,
        line=dict(color='red', width=1))
)

fig.add_trace(
    go.Scatter(
        name="Regressão polinomial",
        x=acao_regressao["Date"],
        y=previsoes_polinomial,
        line=dict(color='blue', width=1))
)



fig.update_layout(paper_bgcolor='rgba(0,0,0,0)', plot_bgcolor='rgba(0,0,0,0)')

fig.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <div>                            <div id="66c76091-0ae3-4382-9e2f-82a874185823" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66c76091-0ae3-4382-9e2f-82a874185823")) {                    Plotly.newPlot(                        "66c76091-0ae3-4382-9e2f-82a874185823",                        [{"close":[11.029999732971191,11.5,11.0,11.100000381469727,11.25,11.75,11.600000381469727,11.65999984741211,11.460000038146973,11.600000381469727,11.59000015258789,11.34000015258789,11.59000015258789,11.449999809265137,11.300000190734863,11.380000114440918,11.25,11.399999618530273,10.930000305175781,10.779999732971191,10.800000190734863,10.619999885559082,10.850000381469727,10.890000343322754,11.140000343322754,12.0,11.149999618530273,10.84000015258789,10.649999618530273,10.649999618530273,10.390000343322754,10.59000015258789,10.59000015258789,10.59000015258789,10.449999809265137,10.1899995803833,10.130000114440918,10.0,10.0,10.050000190734863,9.649999618530273,9.6899995803833,9.75,10.039999961853027,10.199999809265137,10.020000457763672,9.90999984741211,9.699999809265137,9.84000015258789,9.789999961853027,9.550000190734863,9.25,9.140000343322754,9.239999771118164,9.300000190734863,9.300000190734863,9.399999
# 3  2022-08-04 00:00:00-03:00  11.20  12.06  11.20  11.62      11.62  11385600
# 4  2022-08-05 00:00:00-03:00  11.63  11.91  11.32  11.44      11.44   4432100
# ..                       ...    ...    ...    ...    ...        ...       ...
# 94 2022-12-15 00:00:00-03:00   9.12   9.57   8.97   9.07       9.07   5475800
# 95 2022-12-16 00:00:00-03:00   9.06   9.14   8.86   9.04       9.04   7368900
# 96 2022-12-19 00:00:00-03:00   9.13   9.81   9.10   9.38       9.38   9133400
# 97 2022-12-20 00:00:00-03:00   9.33  10.21   9.10   9.97       9.97   9876800
# 98 2022-12-21 00:00:00-03:00   0.00   0.00   0.00  10.00      10.00         0
#
# [99 rows x 7 columns]

# %%
plt.scatter(X, y, color = 'blue')
  
plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'red')
plt.title('Polynomial Regression')
plt.xlabel('Temperature')
plt.ylabel('Pressure')
  
plt.show()

# %%
lin = LinearRegression()
  
lin.fit(X, y)


plt.scatter(X, y, color = 'blue')
  
plt.plot(X, lin.predict(X), color = 'red')
plt.title('Linear Regression')
plt.xlabel('Temperature')
plt.ylabel('Pressure')
  
plt.show()

# %%
acao_regressao
# Out:
#                         Date       Open       High        Low      Close  \
# 0  2022-08-01 00:00:00-03:00  36.939999  36.959999  36.099998  36.500000
# 1  2022-08-02 00:00:00-03:00  36.490002  37.209999  36.320000  36.520000
# 2  2022-08-03 00:00:00-03:00  36.830002  37.009998  36.279999  36.320000
# 3  2022-08-04 00:00:00-03:00  36.459999  37.049999  35.849998  36.880001
# 4  2022-08-05 00:00:00-03:00  36.700001  37.700001  36.689999  37.520000
# ..                       ...        ...        ...        ...        ...
# 79 2022-11-24 00:00:00-03:00  27.100000  28.410000  26.940001  28.120001
# 80 2022-11-25 00:00:00-03:00  28.080000  28.080000  27.219999  27.490000
# 81 2022-11-28 00:00:00-03:00  27.379999  28.370001  27.219999  28.170000
# 82 2022-11-29 00:00:00-03:00  28.400000  29.959999  28.260000  29.379999
# 83 2022-11-30 00:00:00-03:00  29.549999  30.480000  29.500000  30.389999
#
#     Adj Close    Volume
# 0   26.853783  21493500
# 1   26.868498  14991800
# 2   26.721354  12927700
# 3   27.133356  11361700
# 4   27.604218  14332200
# ..        ...       ...
# 79  28.120001  13776300
# 80  27.490000  13019700
# 81  28.170000  12320700
# 82  29.379999  24509100
# 83  30.389999  29533500
#
# [84 rows x 7 columns]

# %%
# Out:
#      Previsao
# 0   38.470695
# 1   38.383030
# 2   38.295366
# 3   38.207701
# 4   38.120037
# ..        ...
# 79  31.545201
# 80  31.457537
# 81  31.369872
# 82  31.282208
# 83  31.194543
#
# [84 rows x 1 columns]
