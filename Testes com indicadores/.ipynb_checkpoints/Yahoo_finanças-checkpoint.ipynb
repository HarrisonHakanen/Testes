# %%
import yfinance as yf
import plotly.express as px
import plotly.graph_objects as go

# Get the data
acao = yf.download("PETR3.SA",interval="1m",period="1d")

# %%
fig = go.Figure()
fig.add_trace(go.Candlestick(
    name='Fechamento', 
    x=df.index, 
    open=df["Open"], 
    high=df["High"],
    low=df["Low"],
    close=df["Close"]))
# Out:
# <div>                            <div id="e4a4e2c7-08ad-49a0-8fd3-8d705318d7e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4a4e2c7-08ad-49a0-8fd3-8d705318d7e1")) {                    Plotly.newPlot(                        "e4a4e2c7-08ad-49a0-8fd3-8d705318d7e1",                        [{"close":[20.799999237060547,21.0,20.989999771118164,20.899999618530273,20.899999618530273,21.020000457763672,21.31999969482422,23.1200008392334,23.799999237060547,24.0,23.950000762939453,24.0,24.049999237060547,24.5,25.239999771118164,26.43000030517578,27.399999618530273,27.920000076293945,28.110000610351562,29.459999084472656,32.0,34.34000015258789,34.0,33.400001525878906,34.04999923706055,33.47999954223633,34.5,36.0,37.66999816894531,37.54999923706055,37.20000
# ...
