# %%
import yfinance as yf
from datetime import datetime

import plotly
import plotly.express as px
import pandas as pd

import dateutil.relativedelta
from datetime import datetime

import plotly.graph_objects as go

import ta_py as ta

# %%
ticker ="PETR3.SA"

acao = yf.download(ticker)

df = acao["2022-01":"2022-11-24"]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
date=df.index.to_list()
highp=df["High"].to_list() # converter tudo pra lista facilita as coisas
lowp=df["Low"].to_list()
tf=25# 25 days to analyse
AroonUp=[] 
AroonDown=[]
AroonDate=[]
x=tf # ele temque comecar no ponto 25 (vulgo ignora-se os 25 primeiros dados)
while x<len(date): # ele vai do ponto 25 até o tamanho máximo da lista
    Aroon_up=((highp[x-tf:x].index(max(highp[x-tf:x])))/float(tf))*100 # ele pega tf periodos anteriores e olha até o ponto atual da análise, buscando o indice que está o ponto máximo dentre as máximas do ativo 
    Aroon_down=((lowp[x-tf:x].index(min(lowp[x-tf:x])))/float(tf))*100# ele pega tf periodos anteriores e olha até o ponto atual da análise, buscando o indice que está o ponto minimo dentre o low do ativo
    AroonUp.append(Aroon_up) 
    AroonDown.append(Aroon_down) 
    AroonDate.append(date[x])
    x+=1
df_teste=pd.DataFrame()
AroonDown=pd.Series(AroonDown)
df_teste["Aroon_Down"]=AroonDown
AroonUp=pd.Series(AroonUp)
df_teste["Aroon_Up"]=AroonUp
AroonDate=pd.Series(AroonDate)
df_teste["Aroon_Date"]=AroonDate
df_teste=df_teste.set_index("Aroon_Date")
#df_teste.tail(40)

# %%
fig = go.Figure()

fig.add_trace(
    go.Scatter(
        name="Fechamento",
        x=df.index,
        y=df["Close"],
        line=dict(color='blue', width=2))
)
# Out:
# <div>                            <div id="b7905eeb-3ce7-4135-89f7-40e6d70e732c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7905eeb-3ce7-4135-89f7-40e6d70e732c")) {                    Plotly.newPlot(                        "b7905eeb-3ce7-4135-89f7-40e6d70e732c",                        [{"line":{"color":"blue","width":2},"name":"Fechamento","x":["2022-01-03T00:00:00-03:00","2022-01-04T00:00:00-03:00","2022-01-05T00:00:00-03:00","2022-01-06T00:00:00-03:00","2022-01-07T00:00:00-03:00","2022-01-10T00:00:00-03:00","2022-01-11T00:00:00-03:00","2022-01-12T00:00:00-03:00","2022-01-13T00:00:00-03:00","2022-01-14T00:00:00-03:00","2022-01-17T00:00:00-03:00","2022-01-18T00:00:00-03:00","2022-01-19T00:00:00-03:00","2022-01-20T00:00:00-03:00","2022-01-21T00:00:00-03:00","2022-01-24T00:00:00-03:00","2022-01-25T00:00:00-03:00","2022-01-26T00:00:00-03:00","2022-01-27T00:00:00-03:00","2022-01-28T00:00:00-03:00","2022-01-31T00:00:00-03:00","2022-02-01T00:00:00-03:00","2022-02-02T00:00:00-03:00","2022-02-03T00:00:00-03:00","2022-02-04T00:00:00-
022-06-02T00:00:00-03:00","2022-06-03T00:00:00-03:00","2022-06-06T00:00:00-03:00","2022-06-07T00:00:00-03:00","2022-06-08T00:00:00-03:00","2022-06-09T00:00:00-03:00","2022-06-10T00:00:00-03:00","2022-06-13T00:00:00-03:00","2022-06-14T00:00:00-03:00","2022-06-15T00:00:00-03:00","2022-06-17T00:00:00-03:00","2022-06-20T00:00:00-03:00","2022-06-21T00:00:00-03:00","2022-06-22T00:00:00-03:00","2022-06-23T00:00:00-03:00","2022-06-24T00:00:00-03:00","2022-06-27T00:00:00-03:00","2022-06-28T00:00:00- ...

# %%
fig2 = go.Figure()

fig2.add_trace(
    go.Scatter(
        name="Aroon Up - Venda",
        x=df_teste.index,
        y=df_teste["Aroon_Up"],
        line=dict(color='green', width=1))
)
fig2.add_trace(
    go.Scatter(
        name="Aroon Down- Compra",
        x=df_teste.index,
        y=df_teste["Aroon_Down"],
        line=dict(color='red', width=1))
)
# Out:
# <div>                            <div id="869e14fb-ba79-40f3-ada7-aa493024db4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("869e14fb-ba79-40f3-ada7-aa493024db4d")) {                    Plotly.newPlot(                        "869e14fb-ba79-40f3-ada7-aa493024db4d",                        [{"line":{"color":"green","width":1},"name":"Aroon Up - Venda","x":["2022-02-07T00:00:00-03:00","2022-02-08T00:00:00-03:00","2022-02-09T00:00:00-03:00","2022-02-10T00:00:00-03:00","2022-02-11T00:00:00-03:00","2022-02-14T00:00:00-03:00","2022-02-15T00:00:00-03:00","2022-02-16T00:00:00-03:00","2022-02-17T00:00:00-03:00","2022-02-18T00:00:00-03:00","2022-02-21T00:00:00-03:00","2022-02-22T00:00:00-03:00","2022-02-23T00:00:00-03:00","2022-02-24T00:00:00-03:00","2022-02-25T00:00:00-03:00","2022-03-02T00:00:00-03:00","2022-03-03T00:00:00-03:00","2022-03-04T00:00:00-03:00","2022-03-07T00:00:00-03:00","2022-03-08T00:00:00-03:00","2022-03-09T00:00:00-03:00","2022-03-10T00:00:00-03:00","2022-03-11T00:00:00-03:00","2022-03-14T00:00:00-03:00","2022-03-15T00:00:00-03:00","2022-03-16T00:00:00-03:00","2022-03-17T00:00:00-03:00","2022-03-18T00:00:00-03:00","2022-03-21T00:00:00-03:00","2022-03-22T00:00:00-03:00","2022-03-23T00:00:00-03:00","2022-03-24T00:00:00-03:00","2022-03-25T00:00:00-03:00","2022-03-28T00:00:00-03:00","2022-03-29T00:00:00-03:00","2022-03-30T00:00:00-03:00","2022-03-31T00:00:00-03:00","2022-04-01T00:00:00-03:00","2022-04-04T00:00:00-03:00","2022-04-05T00:00:00-03:00","2022-04-06T00:00:00-03:00","2022-04-07T00:00:00-03:00","2022-04-08T